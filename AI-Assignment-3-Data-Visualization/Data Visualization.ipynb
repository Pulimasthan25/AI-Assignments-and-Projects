# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns
import matplotlib.image as mpimg

# %%
sns.set(style = "whitegrid",rc = None)

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
flights_data = sns.load_dataset("flights")

# %%
flights_data.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
flights_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_data.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
flights_data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.regplot(x = "year",y = "passengers",data = flights_data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
year = ['1950','1952','1954','1956','1958','1960']
passengers = [454,514,400,634,590,754]

# %%
plt.scatter(year,passengers)
plt.show()

# %%
plt.scatter(year,passengers,linestyle ='solid',color = 'orange' )
plt.show()

# %%
plt.plot(year,passengers,linestyle = 'dotted',color = 'red')

# %%
plt.plot(year,passengers,linestyle = 'dashdot',color = 'red')

# %%
plt.plot(year,passengers,linestyle = 'dashed',color = 'red')

# %%
img=mpimg.imread("tree")

# %%
mgplot=plt.imshow(img)

# %%
plt.imsave("upside.png",img,origin='lower')

# %%
saved=mpimg.imread('upside.png')

# %%
plt.imshow(saved)

# %%
sns.relplot(x='year',y='passengers',data=flights_data)

# %%
sns.relplot(x='year',y='passengers',data=flights_data,kind='line')

# %%
sns.relplot(x='year',y='passengers',data=flights_data,hue='passengers')

# %%
sns.relplot(x='year',y='passengers',data=flights_data,kind='line',ci=False)

# %%
sns.relplot(x='year',y='passengers',data=flights_data,kind='line',hue='passengers')

# %%
sns.relplot(x='year',y='passengers',data=flights_data,kind='line',style='passengers',ci=None)
